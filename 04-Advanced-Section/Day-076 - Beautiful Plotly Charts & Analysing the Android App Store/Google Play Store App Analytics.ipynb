# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                                     App            Category  \
# 8135  VidStatus app - Status Videos & Status Downloader              SOCIAL
# 3603       Diabetes, Blood Pressure, Health Tracker App             MEDICAL
# 3260                                         AP Manager               TOOLS
# 6182                     Step Counter - Calorie Counter  HEALTH_AND_FITNESS
# 6592                     Mupen64+AE FREE (N64 Emulator)                GAME
#
#       Rating  Reviews  Size_MBs   Installs  Type Price Content_Rating  \
# 8135    4.50    25562     31.00  5,000,000  Free     0           Teen
# 3603    4.50      309      5.90     10,000  Free     0       Everyone
# 3260    4.00      177      2.80     10,000  Free     0       Everyone
# 6182    4.00     1577      2.20    500,000  Free     0       Everyone
# 6592    4.00    41759     12.00  1,000,000  Free     0       Everyone
#
#                 Genres      Last_Updated Android_Ver
# 8135            Social    August 2, 2018  4.1 and up
# 3603           Medical    March 15, 2017  4.4 and up
# 3260             Tools       May 4, 2015  2.3 and up
# 6182  Health & Fitness   August 12, 2017  4.4 and up
# 6592            Arcade  January 19, 2014  2.0 and up

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(columns=["Last_Updated", "Android_Ver"])
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# 0   July 28, 2017          4.1 and up
# 1  April 15, 2016          3.0 and up
# 2   July 11, 2018          4.2 and up
# 3   June 28, 2018  Varies with device
# 4  August 6, 2018          4.1 and up

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.Rating.isna().values.sum() # type: ignore
# Out:
# 1474

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.isna().values.any()
# Out:
# False

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().values.any() # type: ignore
# Out:
# True

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
duplicated_rows.head()
# Out:
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres   Last_Updated  \
# 946      11.00      100  Free       0     Mature 17+  Medical   June 6, 2018
# 1133      3.90      100  Free       0     Mature 17+   Dating  July 17, 2018
# 1196      6.50      100  Paid  $12.99       Everyone  Medical  July 25, 2018
# 1231     22.00      100  Free       0       Everyone  Medical  July 25, 2018
# 1247      4.90      100  Free       0     Mature 17+   Dating  July 24, 2018
#
#        Android_Ver
# 946     4.1 and up
# 1133    4.4 and up
# 1196    3.0 and up
# 1231    5.0 and up
# 1247  4.0.3 and up

# %%
duplicated_rows.shape
# Out:
# (474, 12)

# %%
df_apps_clean.drop_duplicates(subset=["App", "Type", "Price"])
df_apps_clean.duplicated().values.any() # type: ignore
# Out:
# True

# %%
df_apps_clean[df_apps_clean.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10806     0           Teen  Social  July 31, 2018  Varies with device
# 10808     0           Teen  Social  July 31, 2018  Varies with device
# 10809     0           Teen  Social  July 31, 2018  Varies with device
# 10810     0           Teen  Social  July 31, 2018  Varies with device

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_highest_rated = df_apps_clean.sort_values(by=["Rating"], ascending=False)
df_highest_rated.head()
# Out:
#                                             App   Category  Rating  Reviews  \
# 21                          KBA-EZ Health Guide    MEDICAL    5.00        4
# 993                                    DV Youth  LIFESTYLE    5.00        5
# 1690                             Exam Result BD     FAMILY    5.00        2
# 1100                               Chenoweth AH    MEDICAL    5.00        1
# 1099  TI-84 CE Graphing Calculator Manual TI 84     FAMILY    5.00        1
#
#       Size_MBs Installs  Type  Price Content_Rating     Genres  \
# 21       25.00        1  Free      0       Everyone    Medical
# 993      15.00      100  Free      0       Everyone  Lifestyle
# 1690      2.60      500  Free      0       Everyone  Education
# 1100     27.00      100  Free      0       Everyone    Medical
# 1099     27.00      100  Paid  $4.99       Everyone  Education
#
#         Last_Updated   Android_Ver
# 21    August 2, 2018  4.0.3 and up
# 993   April 25, 2016  4.0.3 and up
# 1690   July 22, 2017    3.2 and up
# 1100   April 3, 2017  4.0.3 and up
# 1099  March 28, 2018    4.1 and up

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_largest_size = df_apps_clean.sort_values(by=["Size_MBs"], ascending=False)
df_largest_size.head()
# Out:
#                                     App Category  Rating  Reviews  Size_MBs  \
# 7928      Stickman Legends: Shadow Wars     GAME    4.40    38419    100.00
# 9944       Gangster Town: Vice District   FAMILY    4.30    65146    100.00
# 7927        The Walking Dead: Our World     GAME    4.00    22435    100.00
# 8719         Draft Simulator for FUT 18   SPORTS    4.60   162933    100.00
# 8718  Mini Golf King - Multiplayer Game     GAME    4.50   531458    100.00
#
#         Installs  Type  Price Content_Rating      Genres    Last_Updated  \
# 7928   1,000,000  Paid  $0.99   Everyone 10+      Action  August 3, 2018
# 9944  10,000,000  Free      0     Mature 17+  Simulation    May 31, 2018
# 7927   1,000,000  Free      0           Teen      Action  August 1, 2018
# 8719   5,000,000  Free      0       Everyone      Sports    May 11, 2018
# 8718   5,000,000  Free      0       Everyone      Sports   July 20, 2018
#
#        Android_Ver
# 7928    4.1 and up
# 9944    4.0 and up
# 7927    5.0 and up
# 8719    4.1 and up
# 8718  4.0.3 and up

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_most_reviews = df_apps_clean.sort_values(by=["Reviews"], ascending=False)
df_most_reviews.head()
# Out:
#                       App       Category  Rating   Reviews  Size_MBs  \
# 10805            Facebook         SOCIAL    4.10  78158306      5.30
# 10811            Facebook         SOCIAL    4.10  78128208      5.30
# 10789  WhatsApp Messenger  COMMUNICATION    4.40  69119316      3.50
# 10785  WhatsApp Messenger  COMMUNICATION    4.40  69119316      3.50
# 10797  WhatsApp Messenger  COMMUNICATION    4.40  69109672      3.50
#
#             Installs  Type Price Content_Rating         Genres  \
# 10805  1,000,000,000  Free     0           Teen         Social
# 10811  1,000,000,000  Free     0           Teen         Social
# 10789  1,000,000,000  Free     0       Everyone  Communication
# 10785  1,000,000,000  Free     0       Everyone  Communication
# 10797  1,000,000,000  Free     0       Everyone  Communication
#
#          Last_Updated         Android_Ver
# 10805  August 3, 2018  Varies with device
# 10811  August 3, 2018  Varies with device
# 10789  August 3, 2018  Varies with device
# 10785  August 3, 2018  Varies with device
# 10797  August 3, 2018  Varies with device

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           7419
# Teen               1084
# Mature 17+          461
# Everyone 10+        397
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()

# %%
fig = px.pie(
    labels=ratings.index, 
    values=ratings.values,
    names=ratings.index,
    title="Content Ratings"
    )

fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()

# %%
fig = px.pie(
    labels=ratings.index, 
    values=ratings.values,
    names=ratings.index,
    title="Content Ratings",
    hole=0.6
    )

fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
# type(df_apps_clean.Installs.values.any()) # type: ignore
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9365 entries, 21 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9365 non-null   object
#  1   Category        9365 non-null   object
#  2   Rating          9365 non-null   float64
#  3   Reviews         9365 non-null   int64
#  4   Size_MBs        9365 non-null   float64
#  5   Installs        9365 non-null   object
#  6   Type            9365 non-null   object
#  7   Price           9365 non-null   object
#  8   Content_Rating  9365 non-null   object
#  9   Genres          9365 non-null   object
#  10  Last_Updated    9365 non-null   object
#  11  Android_Ver     9365 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 951.1+ KB

# %%
df_apps_clean.Installs.value_counts()
# Out:
# Installs
# 1,000,000        1577
# 10,000,000       1252
# 100,000          1150
# 10,000           1009
# 5,000,000         752
# 1,000             713
# 500,000           538
# 50,000            467
# 5,000             432
# 100,000,000       409
# 100               309
# 50,000,000        289
# 500               201
# 500,000,000        72
# 10                 69
# 1,000,000,000      58
# 50                 56
# 5                   9
# 1                   3
# Name: count, dtype: int64

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(",", "")
df_apps_clean.tail()
# Out:
# C:\Users\boukh\AppData\Local\Temp\ipykernel_3112\1493895297.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   App Category  Rating   Reviews  Size_MBs    Installs  Type  \
# 10836  Subway Surfers     GAME    4.50  27723193     76.00  1000000000  Free
# 10837  Subway Surfers     GAME    4.50  27724094     76.00  1000000000  Free
# 10838  Subway Surfers     GAME    4.50  27725352     76.00  1000000000  Free
# 10839  Subway Surfers     GAME    4.50  27725352     76.00  1000000000  Free
# 10840  Subway Surfers     GAME    4.50  27711703     76.00  1000000000  Free
#
#       Price Content_Rating  Genres   Last_Updated Android_Ver
# 10836     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10837     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10838     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10839     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10840     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up

# %%
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean.Installs.dtype
# type(df_apps_clean.Installs.values.any()) # type: ignore
# Out:
# C:\Users\boukh\AppData\Local\Temp\ipykernel_3112\2090056861.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# dtype('int64')

# %%
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          309
# 500          201
# 1000         713
# 5000         432
# 10000       1009
# 50000        467
# 100000      1150
# 500000       538
# 1000000     1577
# 5000000      752
# 10000000    1252
# 50000000     289
# 100000000    409
# 500000000     72
# 1000000000    58

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
df_apps_clean.Price.dtype
# Out:
# C:\Users\boukh\AppData\Local\Temp\ipykernel_3112\550487664.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\boukh\AppData\Local\Temp\ipykernel_3112\550487664.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# dtype('float64')

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean.sort_values(by=["Price"], ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3897                       I Am Rich     FAMILY    3.60      217      4.90
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# 2282       Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 2281       Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407                    LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629                I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481         A Manual of Acupuncture    MEDICAL    3.50      214     68.00
#
#       Installs  Type  Price Content_Rating         Genres       Last_Updated  \
# 3946     10000  Paid 400.00       Everyone      Lifestyle        May 3, 2018
# 2461      1000  Paid 399.99       Everyone        Finance      June 25, 2018
# 2775      5000  Paid 399.99       Everyone  Entertainment       May 30, 2017
# 3114      5000  Paid 399.99       Everyone        Finance     March 22, 2018
# 5765    100000  Paid 399.99       Everyone      Lifestyle   January 12, 2018
# 3554     10000  Paid 399.99       Everyone      Lifestyle     March 11, 2018
# 1331       100  Paid 399.99       Everyone  Entertainment      July 16, 2018
# 2394      1000  Paid 399.99       Everyone        Finance  December 11, 2017
# 3145      5000  Paid 399.99       Everyone        Finance        May 1, 2017
# 1946      1000  Paid 399.99           Teen        Finance   December 6, 2017
# 3221     10000  Paid 399.99       Everyone  Entertainment       May 19, 2018
# 4606     50000  Paid 399.99       Everyone        Finance  November 12, 2017
# 3897     10000  Paid 389.99       Everyone  Entertainment      June 22, 2018
# 2193      1000  Paid 379.99       Everyone      Lifestyle       July 1, 2018
# 3856     10000  Paid 299.99       Everyone      Lifestyle      July 21, 2018
# 2282      1000  Paid  79.99       Everyone        Medical      June 18, 2018
# 2281      1000  Paid  79.99       Everyone        Medical      June 18, 2018
# 1407       100  Paid  39.99       Everyone        Medical      April 4, 2018
# 2629      1000  Paid  37.99       Everyone      Lifestyle      July 18, 2017
# 2481      1000  Paid  33.99       Everyone        Medical    October 2, 2017
#
#        Android_Ver
# 3946    4.1 and up
# 2461    4.1 and up
# 2775    1.6 and up
# 3114    4.2 and up
# 5765  4.0.3 and up
# 3554    4.4 and up
# 1331    7.0 and up
# 2394    4.1 and up
# 3145    4.4 and up
# 1946  4.0.3 and up
# 3221    4.4 and up
# 4606    4.0 and up
# 3897    4.2 and up
# 2193    4.0 and up
# 3856    4.3 and up
# 2282  4.0.3 and up
# 2281  4.0.3 and up
# 1407    4.1 and up
# 2629  4.0.3 and up
# 2481    4.0 and up

# %%
to_drop = df_apps_clean[df_apps_clean["Price"] >= 250.0]
df_apps_clean.drop(to_drop.index, inplace=True) # type: ignore
df_apps_clean.shape
# Out:
# C:\Users\boukh\AppData\Local\Temp\ipykernel_3112\1400104886.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (9350, 12)

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean.insert(5, "Revenue_Estimate", df_apps_clean.Installs*df_apps_clean.Price)
df_apps_clean.sort_values(by=["Revenue_Estimate"], ascending=False).head(10)
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 9224                      Minecraft       FAMILY    4.50  2375336     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 7479            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7478            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
#
#       Revenue_Estimate  Installs  Type  Price Content_Rating  \
# 9220     69,900,000.00  10000000  Paid   6.99   Everyone 10+
# 9224     69,900,000.00  10000000  Paid   6.99   Everyone 10+
# 8825      9,900,000.00  10000000  Paid   0.99     Mature 17+
# 7151      6,990,000.00   1000000  Paid   6.99     Mature 17+
# 7477      5,990,000.00   1000000  Paid   5.99       Everyone
# 7977      5,990,000.00   1000000  Paid   5.99       Everyone
# 7479      5,990,000.00   1000000  Paid   5.99       Everyone
# 7478      5,990,000.00   1000000  Paid   5.99       Everyone
# 6594      4,990,000.00   1000000  Paid   4.99       Everyone
# 6082      2,995,000.00    500000  Paid   5.99       Everyone
#
#                          Genres       Last_Updated         Android_Ver
# 9220  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 9224  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 8825                     Action      July 12, 2018          4.1 and up
# 7151                     Action     March 21, 2015          3.0 and up
# 7477                Photography      July 25, 2018          4.1 and up
# 7977                  Lifestyle      June 27, 2018          4.0 and up
# 7479                Photography      July 25, 2018          4.1 and up
# 7478                Photography      July 25, 2018          4.1 and up
# 6594                     Action      July 19, 2016          2.3 and up
# 6082                    Weather  November 21, 2017  Varies with device

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean.sort_values('Revenue_Estimate', ascending=False)[:10]
# Out:
# C:\Users\boukh\AppData\Local\Temp\ipykernel_3112\2703497668.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 9224                      Minecraft       FAMILY    4.50  2375336     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 7479            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7478            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
#
#       Revenue_Estimate  Installs  Type  Price Content_Rating  \
# 9220     69,900,000.00  10000000  Paid   6.99   Everyone 10+
# 9224     69,900,000.00  10000000  Paid   6.99   Everyone 10+
# 8825      9,900,000.00  10000000  Paid   0.99     Mature 17+
# 7151      6,990,000.00   1000000  Paid   6.99     Mature 17+
# 7477      5,990,000.00   1000000  Paid   5.99       Everyone
# 7977      5,990,000.00   1000000  Paid   5.99       Everyone
# 7479      5,990,000.00   1000000  Paid   5.99       Everyone
# 7478      5,990,000.00   1000000  Paid   5.99       Everyone
# 6594      4,990,000.00   1000000  Paid   4.99       Everyone
# 6082      2,995,000.00    500000  Paid   5.99       Everyone
#
#                          Genres       Last_Updated         Android_Ver
# 9220  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 9224  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 8825                     Action      July 12, 2018          4.1 and up
# 7151                     Action     March 21, 2015          3.0 and up
# 7477                Photography      July 25, 2018          4.1 and up
# 7977                  Lifestyle      June 27, 2018          4.0 and up
# 7479                Photography      July 25, 2018          4.1 and up
# 7478                Photography      July 25, 2018          4.1 and up
# 6594                     Action      July 19, 2016          2.3 and up
# 6082                    Weather  November 21, 2017  Varies with device

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY             1743
# GAME               1097
# TOOLS               734
# PRODUCTIVITY        351
# MEDICAL             350
# COMMUNICATION       328
# SPORTS              319
# FINANCE             317
# PHOTOGRAPHY         317
# PERSONALIZATION     312
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x = top10_category.index, # index = category name
             y = top10_category.values)
 
bar.show()

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h')
 
h_bar.show()

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')
 
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})

cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
cat_merged_df.sort_values('Installs', ascending=False)
# Out:
#                       App     Installs
# Category
# GAME                 1097  35085862717
# COMMUNICATION         328  32647241530
# PRODUCTIVITY          351  14176070180
# SOCIAL                259  14069841475
# TOOLS                 734  11450724500
# FAMILY               1743  10257676490
# PHOTOGRAPHY           317  10088243130
# NEWS_AND_MAGAZINES    233   7496210650
# TRAVEL_AND_LOCAL      226   6868859300
# VIDEO_PLAYERS         160   6221897200
# SHOPPING              238   3247831540
# ENTERTAINMENT         149   2869160000
# PERSONALIZATION       312   2325341930
# BOOKS_AND_REFERENCE   178   1921291655
# SPORTS                319   1751131465
# HEALTH_AND_FITNESS    297   1583056220
# BUSINESS              303   1001768120
# FINANCE               317    876549400
# EDUCATION             155    871352000
# MAPS_AND_NAVIGATION   124    724267560
# LIFESTYLE             310    537431120
# WEATHER                75    426096500
# FOOD_AND_DRINK        109    273777750
# DATING                195    264295110
# HOUSE_AND_HOME         76    168582000
# ART_AND_DESIGN         62    124233100
# LIBRARIES_AND_DEMO     65     62083000
# COMICS                 58     56036100
# MEDICAL               350     53205576
# AUTO_AND_VEHICLES      73     53129800
# PARENTING              50     31116110
# BEAUTY                 42     26916200
# EVENTS                 45     15949410

# %%
cat_merged_df.shape
# Out:
# (33, 2)

# %%
scatter = px.scatter(cat_merged_df, # data
                    x='App', # column name
                    y='Installs',
                    title='Category Concentration',
                    size='App',
                    hover_name=cat_merged_df.index,
                    color='Installs')
 
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))
 
scatter.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean.Genres.value_counts()
# Out:
# Genres
# Tools                     733
# Entertainment             529
# Education                 468
# Action                    358
# Productivity              351
#                          ...
# Puzzle;Education            1
# Card;Brain Games            1
# Lifestyle;Education         1
# Comics;Creativity           1
# Lifestyle;Pretend Play      1
# Name: count, Length: 115, dtype: int64

# %%
len(df_apps_clean.Genres.unique())
# Out:
# 115

# %%
genres_list = df_apps_clean.Genres.str.split(";", expand=True).stack().value_counts()
genres_list
# Out:
# Tools                      734
# Education                  670
# Entertainment              573
# Action                     375
# Productivity               351
# Medical                    350
# Sports                     337
# Communication              329
# Finance                    317
# Photography                317
# Personalization            312
# Lifestyle                  311
# Business                   303
# Health & Fitness           299
# Casual                     262
# Social                     259
# Shopping                   238
# News & Magazines           233
# Travel & Local             226
# Arcade                     223
# Simulation                 212
# Dating                     195
# Books & Reference          180
# Video Players & Editors    163
# Puzzle                     148
# Action & Adventure         135
# Maps & Navigation          124
# Role Playing               119
# Racing                     114
# Food & Drink               109
# Strategy                   107
# Educational                103
# Pretend Play                89
# Adventure                   89
# House & Home                76
# Weather                     75
# Auto & Vehicles             73
# Brain Games                 69
# Art & Design                65
# Libraries & Demo            65
# Board                       60
# Comics                      58
# Parenting                   50
# Card                        48
# Music & Video               47
# Events                      45
# Beauty                      42
# Casino                      37
# Creativity                  36
# Word                        28
# Trivia                      28
# Music                       24
# Music & Audio                1
# Name: count, dtype: int64

# %%
len(genres_list)
# Out:
# 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
fig = px.bar(genres_list,
             x = genres_list.index, # index = category name
             y = genres_list.values,
             title="Top Genres",
             color=genres_list.values,
             color_continuous_scale=px.colors.sequential.Plasma
            )

fig.update_coloraxes(showscale=False)
fig.update_layout(xaxis_title="Genre",
                  yaxis_title="Number of Apps"
                  )

fig.show()

# %%
df = pd.DataFrame({"Genre": genres_list.index, "Count": genres_list.values})

# fig = px.bar(genres_list,
#              x = genres_list.index[:8], # index = category name
#              y = genres_list.values[:8],
#              title="Top Genres",
#              color=genres_list.index[:8],
#              color_continuous_scale=px.colors.sequential.Plasma
#             )

fig = px.bar(df,
             x = df.Genre[:10], # index = category name
             y = df.Count[:10],
             title="Top Genres",
             color=df.Count[:10],
             color_continuous_scale=px.colors.sequential.Plasma
            )

fig.update_coloraxes(showscale=False)
fig.update_layout(xaxis_title="Genre",
                  yaxis_title="Number of Apps"
                  )

fig.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
